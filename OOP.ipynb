# %% [markdown]
# <a href="https://colab.research.google.com/github/Areej-Munir/Apple-Iphone-Analysis/blob/main/OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #OOP

# %%
class BigObject:
    pass

ob1=BigObject()
ob2=BigObject()
ob3=BigObject()


print(type(None))
print(type(True))
print(type(5))
print(type(5.5))
print(type('Areej'))
print(type([]))
print(type(()))
print(type({}))
print(type(ob1))
# Out:
# <class 'NoneType'>
# <class 'bool'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class '__main__.BigObject'>

# %% [markdown]
# **4. Creating Our Own Objects**

# %%
class PlayerCharacter:
    def __init__(self,name,age):
        self.fname=name
        self.myage=age


    def runfun(self):
        print('run')
        print(68)

p1=PlayerCharacter("Areej",32)
p2=PlayerCharacter("Areej",32)
p2.attack=8

print(p1.fname,p1.myage)
print(p2.fname,p2.myage)
print(p1.runfun())
print(p2.attack)
# Out:
# Areej 32
# Areej 32
# run
# 68
# None
# 8

# %% [markdown]
# **5. Attributes and Methods**

# %%
class PlayerCharacter:
    def __init__(self,name,age):
        self.fname=name
        self.myage=age


    def runfun(self):
        print('run')
        print(68)

p1=PlayerCharacter("Areej",32)
p2=PlayerCharacter("Areej",32)
p2.attack=8

help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
class PlayerCharacter:
    # Class Object Attribute (Its not dynamic)
    membership=True
    def __init__(self,name,age):
        if(PlayerCharacter.membership):
            self.fname=name #attribute
            self.myage=age


    def shout(self):
        print(f'My name is {self.fname}')

    def run(self,hello):
        print(f'My name is {self.fname}')

p1=PlayerCharacter("Areej",32)
p2=PlayerCharacter("Arooj",22)
p2.attack=8

print(p1.run('hello'))
print(p2.shout())
# Out:
# My name is Areej
# None
# My name is Arooj
# None

# %% [markdown]
# **__Init__ Function**

# %%
class PlayerCharacter:
    # Class Object Attribute (Its not dynamic)
    membership=True
    def __init__(self,name="anonymous",age=0):
        if(age>18):
            self.fname=name #attribute
            self.myage=age


    def shout(self):
        print(f'My name is {self.fname}')

p1=PlayerCharacter("Areej",12)
p2=PlayerCharacter("Arooj",22)
p2.attack=8

print(p2.shout())
# Out:
# My name is Arooj
# None

# %% [markdown]
# **Exercise **

# %%
#Given the below class:
class Cat:
    species = 'mammal'
    def __init__(self, name, age):
        self.name = name
        self.age = age


# 1 Instantiate the Cat object with 3 cats
ob1=Cat("Rozii",3)
ob2=Cat("Russi",4)
ob3=Cat("Sweeti",5)

# 2 Create a function that finds the oldest cat
def oldest_cat(*args):
    return max(args)

# 3 Print out: "The oldest cat is x years old.". x will be the oldest cat age by using the function in #2
print(f"Oldest Cat is {oldest_cat(ob1.age,ob2.age,ob3.age)}")
# Out:
# Oldest Cat is 5

# %% [markdown]
# https://www.makeuseof.com/tag/python-instance-static-class-methods/

# %% [markdown]
# Decorator is a function that takes another function as argument and returns a function.
# https://youtu.be/uG4FD0SZ-cQ?si=lQGhjTpzO5J9DEPe\
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
class PlayerCharacter:
    membership = True

    def __init__(self, name, age):
        self.fname = name
        self.myage = age

    @classmethod
    def adding_things(cls, num1, num2):
        return cls("Teddy", num1 + num2)

    @staticmethod
    def adding_things2(num1, num2):
        return num1 + num2

# Corrected indentation: The following lines should be outside the class definition
p3 = PlayerCharacter.adding_things(2, 3)
print(p3.fname)
# Out:
# Teddy

# %%
class PlayerCharacter:
    membership = True # class attribute, meaning it's shared by all instances of the class.

    def __init__(self, name, age):  # Corrected the typo here
        self.fname = name
        self.myage = age

    @classmethod
    def adding_things(cls, num1, num2):
        return cls("Teddy", num1 + num2)

    @staticmethod
    def adding_things2(num1, num2):
        return num1 + num2

# Creating an instance of PlayerCharacter using the class method
p3 = PlayerCharacter.adding_things(2, 3)

# Printing an attribute of the instance
print(p3.fname)  # or print(p3.myage)
# Out:
# Teddy

# %% [markdown]
# class ccccddddk# Encapsulation

# %%
class PlayerCharacter:
    def __init__(self, name, age):
        self.fname = name
        self.myage = age

    def run(self):
        print("run")

    def speak(self):
        print(f"My name is {self.fname}, and I am {self.myage}")

# Creating an instance of the PlayerCharacter class
p1 = PlayerCharacter("Areej", 100)
p1.speak()
# Out:
# My name is Areej, and I am 100

# %%
class PlayerCharacter:
    def __init__(self, name, age):
        self.fname = name
        self.myage = age

# Creating the first instance
p1 = PlayerCharacter("Areej", 100)
print(p1.fname)
print(p1.myage)

# Creating the second instance correctly
p2 = PlayerCharacter("Areej", 300)
print(p2.fname)
print(p2.myage)
# Out:
# Areej
# 100
# Areej
# 300

# %% [markdown]
# # Inheritance
#
# ![image.png](data:image/png;base64,...)

# %%
class Person(object):
    def __init__(self, name, id):
        self.name = name
        self.id = id

    def display(self):
        print(self.name, self.id)

p = Person("Areej", 12212)
p.display()
# Out:
# Areej 12212

# %%
# Parent Class
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def print(self):
        print(self.firstname, self.lastname)

p = Person("Areej", "Munir")
p.print()

# Child Class
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year

    def welcome(self):
        print("Welcome", self.firstname, self.lastname, self.graduationyear)

c = Student("Maira", "Ali", "2023")
c.welcome()
# Out:
# Areej Munir
# Welcome Maira Ali 2023

# %% [markdown]
# ### **Polymorphism**
# The word "polymorphism" means "many forms", and in programming it refers to methods/functions/operators with the same name that can be executed on many objects or classes.

# %%
class Car:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model

    def mov(self):
        print("Drive")

class Boat:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model

    def mov(self):
        print("Sail")

class Plane:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model

    def mov(self):
        print("Fly")


c=Car("Ford","Mustang")
b=Boat("Ibiza","Touring 20")
p=Plane("PIA","343")


for i in (c,b,p):
    print(i.brand)
    print(i.model)
    i.mov()
# Out:
# Ford
# Mustang
# Drive
# Ibiza
# Touring 20
# Sail
# PIA
# 343
# Fly

# %%
class Vehicle:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model

class Car(Vehicle):
    def mov(self):
        print("Drive")

class Boat(Vehicle):
     def mov(self):
        print("Sail")

class Plane(Vehicle):
    def mov(self):
        print("Fly")


c=Car("Ford","Mustang")
b=Boat("Ibiza","Touring 20")
p=Plane("PIA","343")


for i in (c,b,p):
    print(i.brand)
    print(i.model)
    i.mov()
# Out:
# Ford
# Mustang
# Drive
# Ibiza
# Touring 20
# Sail
# PIA
# 343
# Fly

# %%
class Bird:

    def intro(self):
        print("There are many types of birds.")

    def flight(self):
        print("Most of the birds can fly but some cannot.")

class sparrow(Bird):

    def flight(self):
        print("Sparrows can fly.")

class ostrich(Bird):

    def flight(self):
        print("Ostriches cannot fly.")

obj_bird = Bird()
obj_spr = sparrow()
obj_ost = ostrich()

obj_bird.intro()
obj_bird.flight()

obj_spr.intro()
obj_spr.flight()

obj_ost.intro()
obj_ost.flight()
# Out:
# There are many types of birds.
# Most of the birds can fly but some cannot.
# There are many types of birds.
# Sparrows can fly.
# There are many types of birds.
# Ostriches cannot fly.

# %% [markdown]
# ## **Encapsulation**
#
# ![image.png](data:image/png;base64,...)

# %%
class Base:
    def __init__(self):
        self._a = 2  # Protected member

# Creating a derived class
class Derived(Base):
    def __init__(self):
        Base.__init__(self)
        print("Calling protected member of base class: ",self._a)

        self._a = 3 # Modify the protected variable:
        print("Calling modified protected member outside class: ", self._a)


o1 = Derived()
o2 = Base()

# Calling protected member
# Can be accessed but should not be done due to convention
print("Accessing protected member of o1: ", o1._a)

# Accessing the protected variable outside
print("Accessing protected member of o2: ", o2._a)
# Out:
# Calling protected member of base class:  2
# Calling modified protected member outside class:  3
# Accessing protected member of o1:  3
# Accessing protected member of o2:  2

# %%
# "__" double underscore represents private attribute.
# Private attributes start with "__".
class Base:
    def __init__(self):
        self.a = "Areej"
        self.__c = "Munir"

class Derived(Base):
    def __init__(self):

        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling private member of base class: ")
        print(self.__c)
o = Base()
print(o.a)
# Out:
# Areej

# %% [markdown]
# ## **Data Abstraction**
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
from abc import ABC, abstractmethod

class Car(ABC):
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    @abstractmethod
    def print_details(self):
        pass

    def accelerate(self):
        print("Speed Up...")

    def brake_applied(self):
        print("Car stopped")


class Hatchback(Car):
    def print_details(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Year:", self.year)

    def sunroof(self):
        print("No having this feature")


class SUV(Car):
    def print_details(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Year:", self.year)

    def sunroof(self):
        print("Available")


c = Hatchback("Maruti", "Alto", "2023")
c.print_details()
c.accelerate()
c.sunroof()
# Out:
# Brand: Maruti
# Model: Alto
# Year: 2023
# Speed Up...
# No having this feature
